# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.impute import SimpleImputer

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('house-prices/train.csv',usecols=['MSZoning', 'LotFrontage', 'LotArea', 'BldgType', 'OverallQual', 'OverallCond', 'YearBuilt', 'Foundation', 'BsmtCond', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' , 'GrLivArea' , 'KitchenQual' ,'TotRmsAbvGrd' , 'GarageType' , 'GarageCars' , 'GarageArea' , 'GarageQual' , 'GarageCond' , 'PoolArea' ,  'MiscVal' , 'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' , 'ExterQual', 'ExterCond' , 'BsmtQual', 'CentralAir', 'SalePrice'])
df
# Out:
#      MSZoning  LotFrontage  LotArea BldgType  OverallQual  OverallCond  \
# 0          RL         65.0     8450     1Fam            7            5
# 1          RL         80.0     9600     1Fam            6            8
# 2          RL         68.0    11250     1Fam            7            5
# 3          RL         60.0     9550     1Fam            7            5
# 4          RL         84.0    14260     1Fam            8            5
# ...       ...          ...      ...      ...          ...          ...
# 1455       RL         62.0     7917     1Fam            6            5
# 1456       RL         85.0    13175     1Fam            6            6
# 1457       RL         66.0     9042     1Fam            7            9
# 1458       RL         68.0     9717     1Fam            5            6
# 1459       RL         75.0     9937     1Fam            5            6
#
#       YearBuilt RoofStyle RoofMatl Exterior1st  ... GarageType GarageCars  \
# 0          2003     Gable  CompShg     VinylSd  ...     Attchd          2
# 1          1976     Gable  CompShg     MetalSd  ...     Attchd          2
# 2          2001     Gable  CompShg     VinylSd  ...     Attchd          2
# 3          1915     Gable  CompShg     Wd Sdng  ...     Detchd          3
# 4          2000     Gable  CompShg     VinylSd  ...     Attchd          3
# ...         ...       ...      ...         ...  ...        ...        ...
# 1455       1999     Gable  CompShg     VinylSd  ...     Attchd          2
# 1456       1978     Gable  CompShg     Plywood  ...     Attchd          2
# 1457       1941     Gable  CompShg     CemntBd  ...     Attchd          1
# 1458       1950       Hip  CompShg     MetalSd  ...     Attchd          1
# 1459       1965     Gable  CompShg     HdBoard  ...     Attchd          1
#
#      GarageArea GarageQual GarageCond PoolArea  MiscVal SaleType  \
# 0           548         TA         TA        0        0       WD
# 1           460         TA         TA        0        0       WD
# 2           608         TA         TA        0        0       WD
# 3           642         TA         TA        0        0       WD
# 4           836         TA         TA        0        0       WD
# ...         ...        ...        ...      ...      ...      ...
# 1455        460         TA         TA        0        0       WD
# 1456        500         TA         TA        0        0       WD
# 1457        252         TA         TA        0     2500       WD
# 1458        240         TA         TA        0        0       WD
# 1459        276         TA         TA        0        0       WD
#
#       SaleCondition  SalePrice
# 0            Normal     208500
# 1            Normal     181500
# 2            Normal     223500
# 3           Abnorml     140000
# 4            Normal     250000
# ...             ...        ...
# 1455         Normal     175000
# 1456         Normal     210000
# 1457         Normal     266500
# 1458         Normal     142125
# 1459         Normal     147500
#
# [1460 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'BldgType', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'TotalBsmtSF', 'CentralAir', '1stFlrSF', '2ndFlrSF',
#        'GrLivArea', 'KitchenQual', 'TotRmsAbvGrd', 'GarageType', 'GarageCars',
#        'GarageArea', 'GarageQual', 'GarageCond', 'PoolArea', 'MiscVal',
#        'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df.iloc[1,:-1]
# Out:
# MSZoning              RL
# LotFrontage         80.0
# LotArea             9600
# BldgType            1Fam
# OverallQual            6
# OverallCond            8
# YearBuilt           1976
# RoofStyle          Gable
# RoofMatl         CompShg
# Exterior1st      MetalSd
# Exterior2nd      MetalSd
# ExterQual             TA
# ExterCond             TA
# Foundation        CBlock
# BsmtQual              Gd
# BsmtCond              TA
# TotalBsmtSF         1262
# CentralAir             Y
# 1stFlrSF            1262
# 2ndFlrSF               0
# GrLivArea           1262
# KitchenQual           TA
# TotRmsAbvGrd           6
# GarageType        Attchd
# GarageCars             2
# GarageArea           460
# GarageQual            TA
# GarageCond            TA
# PoolArea               0
# MiscVal                0
# SaleType              WD
# SaleCondition     Normal
# Name: 1, dtype: object

# %%
df['YearBuilt'] = pd.to_datetime(df['YearBuilt']).dt.year

# %%
removable_col = [x for x in df.columns if (df[x].isnull().sum() > 0)]
removable_col
# Out:
# ['LotFrontage',
#  'BsmtQual',
#  'BsmtCond',
#  'GarageType',
#  'GarageQual',
#  'GarageCond']

# %%
# df = df[removable_col].dropna()

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=46)

# %%
X_train.sample(30)
# Out:
#      MSZoning  LotFrontage  LotArea BldgType  OverallQual  OverallCond  \
# 628        RL         70.0    11606     1Fam            5            5
# 5          RL         85.0    14115     1Fam            5            5
# 1293       RL         78.0    10140     1Fam            7            5
# 1254       RL         60.0     6931     1Fam            7            5
# 955        RH         82.0     7136   Duplex            6            6
# 968        RM         50.0     5925     1Fam            3            6
# 889        RL        128.0    12160     1Fam            6            4
# 852        RL         53.0     7128     1Fam            7            5
# 534        RL         74.0     9056     1Fam            8            5
# 1417       RL          NaN    16545     1Fam            8            5
# 574        RL         70.0    10500     1Fam            5            7
# 923        RL         50.0     8012   TwnhsE            6            5
# 1290       RL          NaN    14112     1Fam            5            7
# 1251       RL          NaN     3136   TwnhsE            7            5
# 96         RL         78.0    10264     1Fam            7            5
# 420        RM         78.0     7060   Duplex            7            5
# 1077       RL          NaN    15870     1Fam            5            5
# 439        RL         67.0    12354     1Fam            6            8
# 530        RL         85.0    10200     1Fam            6            5
# 86         RL        122.0    11911     1Fam            6            5
# 331        RL         70.0     8176     1Fam            5            6
# 553        RL         67.0     8777     1Fam            4            5
# 29         RM         60.0     6324     1Fam            4            6
# 774        RL        110.0    14226     1Fam            8            5
# 213        RL         43.0    13568     1Fam            5            5
# 1267       RL         89.0    13214     1Fam            9            5
# 644        FV         85.0     9187     1Fam            9            5
# 779        RL         78.0    10530   Duplex            6            5
# 127        RM         55.0     4388     1Fam            5            7
# 75         RM         21.0     1596    Twnhs            4            5
#
#       YearBuilt RoofStyle RoofMatl Exterior1st  ... TotRmsAbvGrd GarageType  \
# 628        1970     Gable  CompShg     Plywood  ...            9     Attchd
# 5          1970     Gable  CompShg     VinylSd  ...            5     Attchd
# 1293       1970     Gable  CompShg     HdBoard  ...            8     Attchd
# 1254       1970     Gable  CompShg     VinylSd  ...            7    BuiltIn
# 955        1970     Gable  CompShg     MetalSd  ...            8     Attchd
# 968        1970     Gable  CompShg     VinylSd  ...            6        NaN
# 889        1970       Hip  CompShg     Wd Sdng  ...            6     Attchd
# 852        1970     Gable  CompShg     MetalSd  ...            7     Detchd
# 534        1970     Gable  CompShg     VinylSd  ...            6     Attchd
# 1417       1970     Gable  CompShg     VinylSd  ...            7     Attchd
# 574        1970   Gambrel  CompShg     MetalSd  ...            5    BuiltIn
# 923        1970     Gable  CompShg     Plywood  ...            5     Attchd
# 1290       1970       Hip  CompShg     Wd Sdng  ...            6     Attchd
# 1251       1970     Gable  CompShg     VinylSd  ...            6     Attchd
# 96         1970     Gable  CompShg     VinylSd  ...            6     Attchd
# 420        1970     Gable  CompShg     VinylSd  ...            8     Attchd
# 1077       1970     Gable  CompShg     VinylSd  ...            6     Attchd
# 439        1970     Gable  CompShg     Wd Sdng  ...            7     Detchd
# 530        1970     Gable  CompShg     HdBoard  ...            5     Attchd
# 86         1970     Gable  CompShg     VinylSd  ...            6    BuiltIn
# 331        1970     Gable  CompShg     Wd Sdng  ...            6     Attchd
# 553        1970     Gable  CompShg     VinylSd  ...            5     Detchd
# 29         1970     Gable  CompShg     MetalSd  ...            4     Detchd
# 774        1970       Hip  CompShg     VinylSd  ...            9     Attchd
# 213        1970     Gable  CompShg     VinylSd  ...            5     Attchd
# 1267       1970       Hip  CompShg      Stucco  ...           10     Attchd
# 644        1970     Gable  CompShg     CemntBd  ...            7     Attchd
# 779        1970     Gable  CompShg     Plywood  ...            4     Attchd
# 127        1970     Gable  CompShg     WdShing  ...            5        NaN
# 75         1970     Gable  CompShg     CemntBd  ...            5    BuiltIn
#
#      GarageCars GarageArea GarageQual GarageCond  PoolArea MiscVal  SaleType  \
# 628           2        504         TA         TA         0       0        WD
# 5             2        480         TA         TA         0     700        WD
# 1293          2        528         TA         TA         0       0        WD
# 1254          2        397         TA         TA         0       0        WD
# 955           2        492         TA         TA         0       0        WD
# 968           0          0        NaN        NaN         0       0        WD
# 889           2        505         TA         TA         0       0        WD
# 852           1        240         TA         TA         0       0        WD
# 534           2        403         TA         TA         0       0        WD
# 1417          3       1069         TA         TA         0       0        WD
# 574           1        288         TA         TA         0       0        WD
# 923           2        533         TA         TA         0       0        WD
# 1290          2        484         TA         TA         0       0        WD
# 1251          2        478         TA         TA         0       0        WD
# 96            2        472         TA         TA         0       0        WD
# 420           4        784         TA         TA         0       0        WD
# 1077          1        299         TA         TA         0       0        WD
# 439           2        528         TA         TA         0     800     ConLI
# 530           2        600         TA         TA         0       0        WD
# 86            2        400         TA         TA         0       0        WD
# 331           1        308         TA         TA         0       0        WD
# 553           2        520         TA         TA         0       0        WD
# 29            1        240         Fa         TA         0       0        WD
# 774           3        895         TA         TA         0       0       New
# 213           2        576         TA         TA         0       0        WD
# 1267          3        746         TA         TA         0       0        WD
# 644           3        478         TA         TA         0       0       New
# 779           2        504         TA         TA         0       0        WD
# 127           0          0        NaN        NaN         0       0        WD
# 75            1        297         TA         TA         0       0        WD
#
#       SaleCondition
# 628          Family
# 5            Normal
# 1293         Normal
# 1254         Normal
# 955          Normal
# 968         Abnorml
# 889          Normal
# 852          Normal
# 534          Normal
# 1417         Normal
# 574          Normal
# 923          Normal
# 1290         Normal
# 1251         Normal
# 96           Normal
# 420          Alloca
# 1077        Abnorml
# 439          Normal
# 530         Abnorml
# 86           Normal
# 331          Normal
# 553          Normal
# 29           Normal
# 774         Partial
# 213          Normal
# 1267         Normal
# 644         Partial
# 779          Normal
# 127          Normal
# 75           Normal
#
# [30 rows x 32 columns]

# %%
X_train['LotArea'].describe()
# Out:
# count      1022.000000
# mean      10704.016634
# std       10526.169757
# min        1300.000000
# 25%        7545.000000
# 50%        9565.500000
# 75%       11712.750000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
categoricalColumns = ['MSZoning', 'BldgType',  'Foundation', 'BsmtCond',   'KitchenQual' , 'GarageType' ,  'GarageQual' , 'GarageCond' ,  'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' , 'ExterQual', 'ExterCond' , 'BsmtQual', 'CentralAir']

cat_impute = ['BsmtCond','GarageType','GarageQual' , 'GarageCond' , 'BsmtQual']

ordinalColumns = ['BsmtCond', 'KitchenQual' ,'GarageQual' , 'GarageCond' ,'ExterQual', 'ExterCond' , 'BsmtQual']
oneHotColumns = ['MSZoning', 'BldgType',  'Foundation',    'GarageType' ,    'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' ,  'CentralAir']

# %%
numaricalColumns = ['LotFrontage','OverallQual', 'OverallCond', 'LotArea','YearBuilt', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' ,'GrLivArea' ,'TotRmsAbvGrd' , 'GarageCars' , 'GarageArea' ,'PoolArea' , 'MiscVal']

num_std= ['OverallQual', 'OverallCond', 'LotArea','YearBuilt', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' ,'GrLivArea' ,'TotRmsAbvGrd' , 'GarageCars' , 'GarageArea' ,'PoolArea' , 'MiscVal']

num_im_st = ['LotFrontage']

# %%
X_train.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'BldgType', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'TotalBsmtSF', 'CentralAir', '1stFlrSF', '2ndFlrSF',
#        'GrLivArea', 'KitchenQual', 'TotRmsAbvGrd', 'GarageType', 'GarageCars',
#        'GarageArea', 'GarageQual', 'GarageCond', 'PoolArea', 'MiscVal',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
numaricalColumns
# Out:
# ['LotFrontage',
#  'OverallQual',
#  'OverallCond',
#  'LotArea',
#  'YearBuilt',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea',
#  'PoolArea',
#  'MiscVal']

# %% [markdown]
# # Impute and Scalling

# %%
numerical_transfromer = Pipeline(
    steps=[
        ("num_imputer",SimpleImputer(strategy='mean')),
        ("numScaler",StandardScaler())
    ]
)


categorical_ordi_transformer = Pipeline(
    steps=[
        ("cat_imputer1",SimpleImputer(strategy='most_frequent')),
        ("ord_encod",OrdinalEncoder(categories=[
            ['NA',	'Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['NA',	'Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['NA',	'Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['NA',	'Po' ,'Fa' ,'TA' ,'Gd','Ex']
        ]))
    ]
)

categorical_oneHot_transformer = Pipeline(
    steps=[
        ("cat_imputer1",SimpleImputer(strategy='most_frequent')),
        ("ohe_encod",OneHotEncoder(handle_unknown='ignore'))
    ]
)

# %% [markdown]
# # Using transformer

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('imp_stand',numerical_transfromer,numaricalColumns),
        ('cat_ordi',categorical_ordi_transformer,ordinalColumns),
        ('cat_oneHot',categorical_oneHot_transformer,oneHotColumns)
    ],remainder='passthrough'    
)

# %%
# clf = Pipeline(
#     steps=[
#         ('preprocessor',preprocessor),
#         ('classifier',LinearRegression())
#     ]
# )

# %%
# clf.fit(X_train,X_test)
X_train_trf = preprocessor.fit_transform(X_train)
X_test_trf = preprocessor.transform(X_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)

X_train_trf = pca.fit_transform(X_train_trf)
X_test_trf = pca.transform(X_test_trf)

# %%
rfr = RandomForestRegressor()

rfr.fit(X_train_trf,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rfr.predict(X_test_trf)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8886160750950424

# %%
# import plotly.express as px
# 
# y_train_trf = y_train.astype(str)
# fig = px.scatter_3d(df, x=X_train_trf[:, 0], y=X_train_trf[:, 1], z=X_train_trf[:, 2],
#                     color=y_train_trf)
# fig.update_layout(
#     margin=dict(l=20, r=20, t=20, b=20),
#     paper_bgcolor="LightSteelBlue",
# )
# fig.show()

# %%
import joblib
joblib.dump(preprocessor,'preprocessor')
joblib.dump(rfr,'price_predictions')
joblib.dump(pca,"PCA")
# Out:
# ['PCA']
